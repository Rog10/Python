# %%
# Question 1
# What is Python and why is it useful? 
# Python is an open sourced programming language and it's useful for analyzing data from very large datasets.

# %%
# Question 2
# Are the following variable names allowed in python?
# 1_message (NO)
# Greeting_message (YES)
# Message_1(YES)
# First name(NO)
# Full_name(YES)

# %%
# Question 3
Message = "hello there!"
print(Message)
# Out:
# hello there!

# %%
# Question 4
First_name = "Roger"
Last_name  = "Lopez"
Email_extension = "@gmail.com"
Email = First_name +""+ Last_name +""+ Email_extension
print(Email)
# Out:
# RogerLopez@gmail.com

# %%
# Question 5
First_name = "Eunice"
Last_name = "GIRON"
full_name = First_name +" "+ Last_name
print(full_name.upper())
print(full_name.lower())
# Out:
# EUNICE GIRON
# eunice giron

# %%
Day = 15
print("Do you want to hangout on the" + " " +str(Day)+"" +"th of the month")
# Out:
# Do you want to hangout on the 15th of the month
